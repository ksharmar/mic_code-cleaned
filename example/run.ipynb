# %%
# %run -i demo_mic_estimation.py
# Out:
# input params...
# ../data/./cascades.txt
# ../data/./labels.txt
# ../data/./train_ids.txt
# user_max= 2930
# extra_users_len/min_cas_length= 0 1
# edge_thr,lookback_count= 0 100
# cascade_count, max_iter, num_negative_samples= 111 10 None
# loading data...
# reading dataset...
# indexing dataset...
# num_empty_cascades 16
# filter by train_ids...
# label distribution after discarding small cascades: [0 1] [49 46]
# creating base_graph...
# added nodes 2930
# processed 0 / 95
# ../parameter_estimation/load_data_util.py:66: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(indexed_cascades)
# added all potential edges
# removed edges below thr
# set edge attributes 0 / 738019
# set edge attributes 5000 / 738019
# set edge attributes 10000 / 738019
# ...
